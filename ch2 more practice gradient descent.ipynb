# %%
# Gradient Descent for Linear Regression
# yhat = wx +b
# loss = (y-yhat)**2 / N
import numpy as np
# Initialize some parameters
x = np.random.randn(10, 1)
y = 2*x + np.random.rand()
# Parameters
w = 0.0
b = 0.0
# Hyperparameter
learning_rate = 0.01


#Create gradient descent function
def descend(x, y, w, b, learning_rate):
    dldw = 0.0
    dldb = 0.0
    N = x.shape[0]
    # loss = (y-(wx+b)))**2
    for xi, yi in zip(x, y):
        dldw = -2*xi*(yi-(w*xi+b))
        dldb = -2*(yi-(w*xi+b))

    # Make an update to the w parameter
    x = w - learning_rate*(1/N)*dldw
    b = b - learning_rate*(1/N)*dldb
    return w, b



#Iteratively make updates
for epoch in range(400):
    w, b = descend(x,y,w,b,learning_rate)
    yhat = w*x + b
    loss = np.divide(np.sum((y-yhat)**2, axis=0), x.shape[0])
    print(f'{epoch} loss is {loss}, parameters w:{w}, b:{b}')
# Out:
# 0 loss is [4.05393351], parameters w:0.0, b:[0.00025498]
# 1 loss is [4.05406965], parameters w:0.0, b:[0.00050945]
# 2 loss is [4.05420566], parameters w:0.0, b:[0.00076341]
# 3 loss is [4.05434152], parameters w:0.0, b:[0.00101686]
# 4 loss is [4.05447724], parameters w:0.0, b:[0.00126981]
# 5 loss is [4.05461281], parameters w:0.0, b:[0.00152225]
# 6 loss is [4.05474824], parameters w:0.0, b:[0.00177418]
# 7 loss is [4.05488352], parameters w:0.0, b:[0.00202561]
# 8 loss is [4.05501866], parameters w:0.0, b:[0.00227654]
# 9 loss is [4.05515366], parameters w:0.0, b:[0.00252697]
# 10 loss is [4.05528851], parameters w:0.0, b:[0.00277689]
# 11 loss is [4.05542322], parameters w:0.0, b:[0.00302632]
# 12 loss is [4.05555778], parameters w:0.0, b:[0.00327524]
# 13 loss is [4.05569219], parameters w:0.0, b:[0.00352367]
# 14 loss is [4.05582646], parameters w:0.0, b:[0.0037716]
# 15 loss is [4.05596059], parameters w:0.0, b:[0.00401904]
# 16 loss is [4.05609456], parameters w:0.0, b:[0.00426598]
# 17 loss is [4.05622839], parameters w:0.0, b:[0.00451243]
# 18 loss is [4.05636208], parameters w:0.0, b:[0.00475838]
# 19 loss is [4.05649561], parameters w:0.0, b:[0.00500384]
# 20 loss is [4.056629], parameters w:0.0, b:[0.00524882]
# 21 loss is [4.05676225], parameters w:0.0, b:[0.0054933]
# 22 loss is [4.05689534], parameters w:0.0, b:[0.00573729]
# 23 loss is [4.05702829], parameters w:0.0, b:[0.00598079]
# 24 loss is [4.05716109], parameters w:0.0, b:[0.00622381]
# 25 loss is [4.05729375], parameters w:0.0, b:[0.00646634]
# 26 loss is [4.05742625], parameters w:0.0, b:[0.00670839]
# 27 loss is [4.05755861], parameters w:0.0, b:[0.00694995]
# 28 loss is [4.05769082], parameters w:0.0, b:[0.00719103]
# 29 loss is [4.05782288], parameters w:0.0, b:[0.00743163]
# 30 loss is [4.05795479], parameters w:0.0, b:[0.00767174]
# 31 loss is [4.05808655], parameters w:0.0, b:[0.00791138]
# 32 loss is [4.05821816], parameters w:0.0, b:[0.00815054]
# 33 loss is [4.05834963], parameters w:0.0, b:[0.00838921]
# 34 loss is [4.05848094], parameters w:0.0, b:[0.00862742]
# 35 loss is [4.05861211], parameters w:0.0, b:[0.00886514]
# 36 loss is [4.05874312], parameters w:0.0, b:[0.00910239]
# 37 loss is [4.05887399], parameters w:0.0, b:[0.00933916]
# 38 loss is [4.0590047], parameters w:0.0, b:[0.00957546]
# 39 loss is [4.05913527], parameters w:0.0, b:[0.00981129]
# 40 loss is [4.05926569], parameters w:0.0, b:[0.01004665]
# 41 loss is [4.05939595], parameters w:0.0, b:[0.01028153]
# 42 loss is [4.05952607], parameters w:0.0, b:[0.01051595]
# 43 loss is [4.05965603], parameters w:0.0, b:[0.0107499]
# 44 loss is [4.05978584], parameters w:0.0, b:[0.01098338]
# 45 loss is [4.05991551], parameters w:0.0, b:[0.01121639]
# 46 loss is [4.06004502], parameters w:0.0, b:[0.01144894]
# 47 loss is [4.06017438], parameters w:0.0, b:[0.01168102]
# 48 loss is [4.06030359], parameters w:0.0, b:[0.01191263]
# 49 loss is [4.06043264], parameters w:0.0, b:[0.01214379]
# 50 loss is [4.06056155], parameters w:0.0, b:[0.01237448]
# 51 loss is [4.0606903], parameters w:0.0, b:[0.01260471]
# 52 loss is [4.06081891], parameters w:0.0, b:[0.01283448]
# 53 loss is [4.06094736], parameters w:0.0, b:[0.01306379]
# 54 loss is [4.06107565], parameters w:0.0, b:[0.01329264]
# 55 loss is [4.0612038], parameters w:0.0, b:[0.01352104]
# 56 loss is [4.06133179], parameters w:0.0, b:[0.01374897]
# 57 loss is [4.06145963], parameters w:0.0, b:[0.01397645]
# 58 loss is [4.06158732], parameters w:0.0, b:[0.01420348]
# 59 loss is [4.06171486], parameters w:0.0, b:[0.01443005]
# 60 loss is [4.06184224], parameters w:0.0, b:[0.01465617]
# 61 loss is [4.06196947], parameters w:0.0, b:[0.01488184]
# 62 loss is [4.06209655], parameters w:0.0, b:[0.01510705]
# 63 loss is [4.06222348], parameters w:0.0, b:[0.01533182]
# 64 loss is [4.06235025], parameters w:0.0, b:[0.01555613]
# 65 loss is [4.06247687], parameters w:0.0, b:[0.01578]
# 66 loss is [4.06260333], parameters w:0.0, b:[0.01600342]
# 67 loss is [4.06272964], parameters w:0.0, b:[0.01622639]
# 68 loss is [4.0628558], parameters w:0.0, b:[0.01644892]
# 69 loss is [4.06298181], parameters w:0.0, b:[0.016671]
# 70 loss is [4.06310766], parameters w:0.0, b:[0.01689264]
# 71 loss is [4.06323336], parameters w:0.0, b:[0.01711383]
# 72 loss is [4.0633589], parameters w:0.0, b:[0.01733458]
# 73 loss is [4.06348429], parameters w:0.0, b:[0.01755489]
# 74 loss is [4.06360953], parameters w:0.0, b:[0.01777476]
# 75 loss is [4.06373461], parameters w:0.0, b:[0.01799419]
# 76 loss is [4.06385953], parameters w:0.0, b:[0.01821318]
# 77 loss is [4.06398431], parameters w:0.0, b:[0.01843174]
# 78 loss is [4.06410893], parameters w:0.0, b:[0.01864985]
# 79 loss is [4.06423339], parameters w:0.0, b:[0.01886753]
# 80 loss is [4.0643577], parameters w:0.0, b:[0.01908477]
# 81 loss is [4.06448186], parameters w:0.0, b:[0.01930158]
# 82 loss is [4.06460586], parameters w:0.0, b:[0.01951796]
# 83 loss is [4.0647297], parameters w:0.0, b:[0.0197339]
# 84 loss is [4.06485339], parameters w:0.0, b:[0.01994941]
# 85 loss is [4.06497693], parameters w:0.0, b:[0.0201645]
# 86 loss is [4.06510031], parameters w:0.0, b:[0.02037915]
# 87 loss is [4.06522354], parameters w:0.0, b:[0.02059337]
# 88 loss is [4.06534661], parameters w:0.0, b:[0.02080716]
# 89 loss is [4.06546953], parameters w:0.0, b:[0.02102052]
# 90 loss is [4.06559229], parameters w:0.0, b:[0.02123346]
# 91 loss is [4.0657149], parameters w:0.0, b:[0.02144597]
# 92 loss is [4.06583735], parameters w:0.0, b:[0.02165806]
# 93 loss is [4.06595965], parameters w:0.0, b:[0.02186972]
# 94 loss is [4.06608179], parameters w:0.0, b:[0.02208096]
# 95 loss is [4.06620377], parameters w:0.0, b:[0.02229178]
# 96 loss is [4.06632561], parameters w:0.0, b:[0.02250218]
# 97 loss is [4.06644728], parameters w:0.0, b:[0.02271215]
# 98 loss is [4.0665688], parameters w:0.0, b:[0.02292171]
# 99 loss is [4.06669016], parameters w:0.0, b:[0.02313084]
# 100 loss is [4.06681137], parameters w:0.0, b:[0.02333956]
# 101 loss is [4.06693243], parameters w:0.0, b:[0.02354786]
# 102 loss is [4.06705332], parameters w:0.0, b:[0.02375574]
# 103 loss is [4.06717407], parameters w:0.0, b:[0.02396321]
# 104 loss is [4.06729465], parameters w:0.0, b:[0.02417026]
# 105 loss is [4.06741508], parameters w:0.0, b:[0.0243769]
# 106 loss is [4.06753536], parameters w:0.0, b:[0.02458313]
# 107 loss is [4.06765548], parameters w:0.0, b:[0.02478894]
# 108 loss is [4.06777544], parameters w:0.0, b:[0.02499434]
# 109 loss is [4.06789525], parameters w:0.0, b:[0.02519933]
# 110 loss is [4.0680149], parameters w:0.0, b:[0.02540391]
# 111 loss is [4.0681344], parameters w:0.0, b:[0.02560808]
# 112 loss is [4.06825374], parameters w:0.0, b:[0.02581185]
# 113 loss is [4.06837292], parameters w:0.0, b:[0.0260152]
# 114 loss is [4.06849195], parameters w:0.0, b:[0.02621815]
# 115 loss is [4.06861082], parameters w:0.0, b:[0.02642069]
# 116 loss is [4.06872954], parameters w:0.0, b:[0.02662283]
# 117 loss is [4.0688481], parameters w:0.0, b:[0.02682457]
# 118 loss is [4.0689665], parameters w:0.0, b:[0.0270259]
# 119 loss is [4.06908475], parameters w:0.0, b:[0.02722682]
# 120 loss is [4.06920285], parameters w:0.0, b:[0.02742735]
# 121 loss is [4.06932078], parameters w:0.0, b:[0.02762747]
# 122 loss is [4.06943856], parameters w:0.0, b:[0.0278272]
# 123 loss is [4.06955619], parameters w:0.0, b:[0.02802652]
# 124 loss is [4.06967366], parameters w:0.0, b:[0.02822545]
# 125 loss is [4.06979097], parameters w:0.0, b:[0.02842398]
# 126 loss is [4.06990812], parameters w:0.0, b:[0.02862211]
# 127 loss is [4.07002513], parameters w:0.0, b:[0.02881984]
# 128 loss is [4.07014197], parameters w:0.0, b:[0.02901718]
# 129 loss is [4.07025866], parameters w:0.0, b:[0.02921413]
# 130 loss is [4.07037519], parameters w:0.0, b:[0.02941068]
# 131 loss is [4.07049157], parameters w:0.0, b:[0.02960684]
# 132 loss is [4.07060779], parameters w:0.0, b:[0.0298026]
# 133 loss is [4.07072385], parameters w:0.0, b:[0.02999797]
# 134 loss is [4.07083976], parameters w:0.0, b:[0.03019296]
# 135 loss is [4.07095551], parameters w:0.0, b:[0.03038755]
# 136 loss is [4.07107111], parameters w:0.0, b:[0.03058176]
# 137 loss is [4.07118655], parameters w:0.0, b:[0.03077557]
# 138 loss is [4.07130183], parameters w:0.0, b:[0.030969]
# 139 loss is [4.07141696], parameters w:0.0, b:[0.03116204]
# 140 loss is [4.07153193], parameters w:0.0, b:[0.0313547]
# 141 loss is [4.07164675], parameters w:0.0, b:[0.03154696]
# 142 loss is [4.07176141], parameters w:0.0, b:[0.03173885]
# 143 loss is [4.07187591], parameters w:0.0, b:[0.03193035]
# 144 loss is [4.07199026], parameters w:0.0, b:[0.03212147]
# 145 loss is [4.07210446], parameters w:0.0, b:[0.03231221]
# 146 loss is [4.07221849], parameters w:0.0, b:[0.03250256]
# 147 loss is [4.07233237], parameters w:0.0, b:[0.03269254]
# 148 loss is [4.0724461], parameters w:0.0, b:[0.03288213]
# 149 loss is [4.07255967], parameters w:0.0, b:[0.03307134]
# 150 loss is [4.07267308], parameters w:0.0, b:[0.03326018]
# 151 loss is [4.07278634], parameters w:0.0, b:[0.03344864]
# 152 loss is [4.07289944], parameters w:0.0, b:[0.03363672]
# 153 loss is [4.07301239], parameters w:0.0, b:[0.03382443]
# 154 loss is [4.07312518], parameters w:0.0, b:[0.03401176]
# 155 loss is [4.07323782], parameters w:0.0, b:[0.03419871]
# 156 loss is [4.0733503], parameters w:0.0, b:[0.03438529]
# 157 loss is [4.07346262], parameters w:0.0, b:[0.0345715]
# 158 loss is [4.07357479], parameters w:0.0, b:[0.03475734]
# 159 loss is [4.0736868], parameters w:0.0, b:[0.0349428]
# 160 loss is [4.07379866], parameters w:0.0, b:[0.0351279]
# 161 loss is [4.07391036], parameters w:0.0, b:[0.03531262]
# 162 loss is [4.07402191], parameters w:0.0, b:[0.03549697]
# 163 loss is [4.0741333], parameters w:0.0, b:[0.03568096]
# 164 loss is [4.07424454], parameters w:0.0, b:[0.03586458]
# 165 loss is [4.07435562], parameters w:0.0, b:[0.03604783]
# 166 loss is [4.07446655], parameters w:0.0, b:[0.03623071]
# 167 loss is [4.07457732], parameters w:0.0, b:[0.03641323]
# 168 loss is [4.07468793], parameters w:0.0, b:[0.03659538]
# 169 loss is [4.07479839], parameters w:0.0, b:[0.03677717]
# 170 loss is [4.0749087], parameters w:0.0, b:[0.03695859]
# 171 loss is [4.07501885], parameters w:0.0, b:[0.03713966]
# 172 loss is [4.07512885], parameters w:0.0, b:[0.03732036]
# 173 loss is [4.07523869], parameters w:0.0, b:[0.03750069]
# 174 loss is [4.07534837], parameters w:0.0, b:[0.03768067]
# 175 loss is [4.0754579], parameters w:0.0, b:[0.03786029]
# 176 loss is [4.07556728], parameters w:0.0, b:[0.03803955]
# 177 loss is [4.0756765], parameters w:0.0, b:[0.03821845]
# 178 loss is [4.07578557], parameters w:0.0, b:[0.03839699]
# 179 loss is [4.07589448], parameters w:0.0, b:[0.03857518]
# 180 loss is [4.07600324], parameters w:0.0, b:[0.03875301]
# 181 loss is [4.07611185], parameters w:0.0, b:[0.03893048]
# 182 loss is [4.07622029], parameters w:0.0, b:[0.0391076]
# 183 loss is [4.07632859], parameters w:0.0, b:[0.03928436]
# 184 loss is [4.07643673], parameters w:0.0, b:[0.03946077]
# 185 loss is [4.07654472], parameters w:0.0, b:[0.03963683]
# 186 loss is [4.07665255], parameters w:0.0, b:[0.03981253]
# 187 loss is [4.07676023], parameters w:0.0, b:[0.03998789]
# 188 loss is [4.07686775], parameters w:0.0, b:[0.04016289]
# 189 loss is [4.07697512], parameters w:0.0, b:[0.04033754]
# 190 loss is [4.07708234], parameters w:0.0, b:[0.04051185]
# 191 loss is [4.0771894], parameters w:0.0, b:[0.0406858]
# 192 loss is [4.07729631], parameters w:0.0, b:[0.04085941]
# 193 loss is [4.07740306], parameters w:0.0, b:[0.04103267]
# 194 loss is [4.07750967], parameters w:0.0, b:[0.04120559]
# 195 loss is [4.07761611], parameters w:0.0, b:[0.04137815]
# 196 loss is [4.07772241], parameters w:0.0, b:[0.04155038]
# 197 loss is [4.07782855], parameters w:0.0, b:[0.04172226]
# 198 loss is [4.07793454], parameters w:0.0, b:[0.04189379]
# 199 loss is [4.07804037], parameters w:0.0, b:[0.04206498]
# 200 loss is [4.07814605], parameters w:0.0, b:[0.04223583]
# 201 loss is [4.07825158], parameters w:0.0, b:[0.04240634]
# 202 loss is [4.07835695], parameters w:0.0, b:[0.0425765]
# 203 loss is [4.07846217], parameters w:0.0, b:[0.04274633]
# 204 loss is [4.07856724], parameters w:0.0, b:[0.04291582]
# 205 loss is [4.07867216], parameters w:0.0, b:[0.04308496]
# 206 loss is [4.07877692], parameters w:0.0, b:[0.04325377]
# 207 loss is [4.07888153], parameters w:0.0, b:[0.04342225]
# 208 loss is [4.07898599], parameters w:0.0, b:[0.04359038]
# 209 loss is [4.0790903], parameters w:0.0, b:[0.04375818]
# 210 loss is [4.07919445], parameters w:0.0, b:[0.04392564]
# 211 loss is [4.07929845], parameters w:0.0, b:[0.04409277]
# 212 loss is [4.0794023], parameters w:0.0, b:[0.04425956]
# 213 loss is [4.07950599], parameters w:0.0, b:[0.04442602]
# 214 loss is [4.07960954], parameters w:0.0, b:[0.04459215]
# 215 loss is [4.07971293], parameters w:0.0, b:[0.04475795]
# 216 loss is [4.07981617], parameters w:0.0, b:[0.04492341]
# 217 loss is [4.07991925], parameters w:0.0, b:[0.04508854]
# 218 loss is [4.08002219], parameters w:0.0, b:[0.04525334]
# 219 loss is [4.08012497], parameters w:0.0, b:[0.04541782]
# 220 loss is [4.08022761], parameters w:0.0, b:[0.04558196]
# 221 loss is [4.08033009], parameters w:0.0, b:[0.04574577]
# 222 loss is [4.08043242], parameters w:0.0, b:[0.04590926]
# 223 loss is [4.0805346], parameters w:0.0, b:[0.04607242]
# 224 loss is [4.08063662], parameters w:0.0, b:[0.04623526]
# 225 loss is [4.0807385], parameters w:0.0, b:[0.04639777]
# 226 loss is [4.08084022], parameters w:0.0, b:[0.04655995]
# 227 loss is [4.0809418], parameters w:0.0, b:[0.04672181]
# 228 loss is [4.08104322], parameters w:0.0, b:[0.04688334]
# 229 loss is [4.08114449], parameters w:0.0, b:[0.04704456]
# 230 loss is [4.08124561], parameters w:0.0, b:[0.04720545]
# 231 loss is [4.08134658], parameters w:0.0, b:[0.04736601]
# 232 loss is [4.0814474], parameters w:0.0, b:[0.04752626]
# 233 loss is [4.08154807], parameters w:0.0, b:[0.04768619]
# 234 loss is [4.08164859], parameters w:0.0, b:[0.0478458]
# 235 loss is [4.08174896], parameters w:0.0, b:[0.04800508]
# 236 loss is [4.08184918], parameters w:0.0, b:[0.04816405]
# 237 loss is [4.08194925], parameters w:0.0, b:[0.0483227]
# 238 loss is [4.08204917], parameters w:0.0, b:[0.04848104]
# 239 loss is [4.08214894], parameters w:0.0, b:[0.04863905]
# 240 loss is [4.08224856], parameters w:0.0, b:[0.04879675]
# 241 loss is [4.08234803], parameters w:0.0, b:[0.04895414]
# 242 loss is [4.08244735], parameters w:0.0, b:[0.04911121]
# 243 loss is [4.08254652], parameters w:0.0, b:[0.04926797]
# 244 loss is [4.08264554], parameters w:0.0, b:[0.04942441]
# 245 loss is [4.08274441], parameters w:0.0, b:[0.04958054]
# 246 loss is [4.08284313], parameters w:0.0, b:[0.04973636]
# 247 loss is [4.08294171], parameters w:0.0, b:[0.04989187]
# 248 loss is [4.08304013], parameters w:0.0, b:[0.05004706]
# 249 loss is [4.08313841], parameters w:0.0, b:[0.05020195]
# 250 loss is [4.08323654], parameters w:0.0, b:[0.05035652]
# 251 loss is [4.08333451], parameters w:0.0, b:[0.05051079]
# 252 loss is [4.08343234], parameters w:0.0, b:[0.05066475]
# 253 loss is [4.08353003], parameters w:0.0, b:[0.0508184]
# 254 loss is [4.08362756], parameters w:0.0, b:[0.05097174]
# 255 loss is [4.08372495], parameters w:0.0, b:[0.05112477]
# 256 loss is [4.08382218], parameters w:0.0, b:[0.0512775]
# 257 loss is [4.08391927], parameters w:0.0, b:[0.05142993]
# 258 loss is [4.08401621], parameters w:0.0, b:[0.05158205]
# 259 loss is [4.08411301], parameters w:0.0, b:[0.05173386]
# 260 loss is [4.08420965], parameters w:0.0, b:[0.05188537]
# 261 loss is [4.08430615], parameters w:0.0, b:[0.05203658]
# 262 loss is [4.0844025], parameters w:0.0, b:[0.05218749]
# 263 loss is [4.08449871], parameters w:0.0, b:[0.05233809]
# 264 loss is [4.08459476], parameters w:0.0, b:[0.05248839]
# 265 loss is [4.08469067], parameters w:0.0, b:[0.0526384]
# 266 loss is [4.08478644], parameters w:0.0, b:[0.0527881]
# 267 loss is [4.08488205], parameters w:0.0, b:[0.0529375]
# 268 loss is [4.08497752], parameters w:0.0, b:[0.05308661]
# 269 loss is [4.08507284], parameters w:0.0, b:[0.05323541]
# 270 loss is [4.08516802], parameters w:0.0, b:[0.05338392]
# 271 loss is [4.08526305], parameters w:0.0, b:[0.05353213]
# 272 loss is [4.08535793], parameters w:0.0, b:[0.05368005]
# 273 loss is [4.08545267], parameters w:0.0, b:[0.05382767]
# 274 loss is [4.08554726], parameters w:0.0, b:[0.05397499]
# 275 loss is [4.08564171], parameters w:0.0, b:[0.05412202]
# 276 loss is [4.08573601], parameters w:0.0, b:[0.05426875]
# 277 loss is [4.08583016], parameters w:0.0, b:[0.0544152]
# 278 loss is [4.08592417], parameters w:0.0, b:[0.05456134]
# 279 loss is [4.08601803], parameters w:0.0, b:[0.0547072]
# 280 loss is [4.08611175], parameters w:0.0, b:[0.05485277]
# 281 loss is [4.08620532], parameters w:0.0, b:[0.05499804]
# 282 loss is [4.08629875], parameters w:0.0, b:[0.05514302]
# 283 loss is [4.08639203], parameters w:0.0, b:[0.05528772]
# 284 loss is [4.08648517], parameters w:0.0, b:[0.05543212]
# 285 loss is [4.08657816], parameters w:0.0, b:[0.05557623]
# 286 loss is [4.08667101], parameters w:0.0, b:[0.05572006]
# 287 loss is [4.08676372], parameters w:0.0, b:[0.0558636]
# 288 loss is [4.08685628], parameters w:0.0, b:[0.05600685]
# 289 loss is [4.08694869], parameters w:0.0, b:[0.05614982]
# 290 loss is [4.08704096], parameters w:0.0, b:[0.0562925]
# 291 loss is [4.08713309], parameters w:0.0, b:[0.05643489]
# 292 loss is [4.08722507], parameters w:0.0, b:[0.056577]
# 293 loss is [4.08731691], parameters w:0.0, b:[0.05671883]
# 294 loss is [4.08740861], parameters w:0.0, b:[0.05686037]
# 295 loss is [4.08750016], parameters w:0.0, b:[0.05700163]
# 296 loss is [4.08759157], parameters w:0.0, b:[0.0571426]
# 297 loss is [4.08768284], parameters w:0.0, b:[0.0572833]
# 298 loss is [4.08777396], parameters w:0.0, b:[0.05742371]
# 299 loss is [4.08786494], parameters w:0.0, b:[0.05756384]
# 300 loss is [4.08795578], parameters w:0.0, b:[0.05770369]
# 301 loss is [4.08804648], parameters w:0.0, b:[0.05784326]
# 302 loss is [4.08813703], parameters w:0.0, b:[0.05798256]
# 303 loss is [4.08822744], parameters w:0.0, b:[0.05812157]
# 304 loss is [4.08831771], parameters w:0.0, b:[0.05826031]
# 305 loss is [4.08840783], parameters w:0.0, b:[0.05839876]
# 306 loss is [4.08849781], parameters w:0.0, b:[0.05853695]
# 307 loss is [4.08858766], parameters w:0.0, b:[0.05867485]
# 308 loss is [4.08867736], parameters w:0.0, b:[0.05881248]
# 309 loss is [4.08876691], parameters w:0.0, b:[0.05894983]
# 310 loss is [4.08885633], parameters w:0.0, b:[0.05908691]
# 311 loss is [4.08894561], parameters w:0.0, b:[0.05922372]
# 312 loss is [4.08903474], parameters w:0.0, b:[0.05936025]
# 313 loss is [4.08912373], parameters w:0.0, b:[0.05949651]
# 314 loss is [4.08921258], parameters w:0.0, b:[0.0596325]
# 315 loss is [4.0893013], parameters w:0.0, b:[0.05976821]
# 316 loss is [4.08938987], parameters w:0.0, b:[0.05990365]
# 317 loss is [4.0894783], parameters w:0.0, b:[0.06003882]
# 318 loss is [4.08956659], parameters w:0.0, b:[0.06017373]
# 319 loss is [4.08965474], parameters w:0.0, b:[0.06030836]
# 320 loss is [4.08974274], parameters w:0.0, b:[0.06044272]
# 321 loss is [4.08983061], parameters w:0.0, b:[0.06057681]
# 322 loss is [4.08991834], parameters w:0.0, b:[0.06071064]
# 323 loss is [4.09000593], parameters w:0.0, b:[0.0608442]
# 324 loss is [4.09009338], parameters w:0.0, b:[0.06097749]
# 325 loss is [4.09018069], parameters w:0.0, b:[0.06111051]
# 326 loss is [4.09026786], parameters w:0.0, b:[0.06124327]
# 327 loss is [4.09035489], parameters w:0.0, b:[0.06137576]
# 328 loss is [4.09044179], parameters w:0.0, b:[0.06150799]
# 329 loss is [4.09052854], parameters w:0.0, b:[0.06163995]
# 330 loss is [4.09061516], parameters w:0.0, b:[0.06177165]
# 331 loss is [4.09070163], parameters w:0.0, b:[0.06190309]
# 332 loss is [4.09078797], parameters w:0.0, b:[0.06203426]
# 333 loss is [4.09087417], parameters w:0.0, b:[0.06216517]
# 334 loss is [4.09096023], parameters w:0.0, b:[0.06229582]
# 335 loss is [4.09104615], parameters w:0.0, b:[0.06242621]
# 336 loss is [4.09113194], parameters w:0.0, b:[0.06255634]
# 337 loss is [4.09121759], parameters w:0.0, b:[0.0626862]
# 338 loss is [4.0913031], parameters w:0.0, b:[0.06281581]
# 339 loss is [4.09138847], parameters w:0.0, b:[0.06294516]
# 340 loss is [4.0914737], parameters w:0.0, b:[0.06307425]
# 341 loss is [4.0915588], parameters w:0.0, b:[0.06320308]
# 342 loss is [4.09164376], parameters w:0.0, b:[0.06333165]
# 343 loss is [4.09172859], parameters w:0.0, b:[0.06345997]
# 344 loss is [4.09181327], parameters w:0.0, b:[0.06358802]
# 345 loss is [4.09189782], parameters w:0.0, b:[0.06371583]
# 346 loss is [4.09198224], parameters w:0.0, b:[0.06384338]
# 347 loss is [4.09206651], parameters w:0.0, b:[0.06397067]
# 348 loss is [4.09215065], parameters w:0.0, b:[0.06409771]
# 349 loss is [4.09223466], parameters w:0.0, b:[0.06422449]
# 350 loss is [4.09231853], parameters w:0.0, b:[0.06435102]
# 351 loss is [4.09240226], parameters w:0.0, b:[0.0644773]
# 352 loss is [4.09248586], parameters w:0.0, b:[0.06460332]
# 353 loss is [4.09256932], parameters w:0.0, b:[0.06472909]
# 354 loss is [4.09265265], parameters w:0.0, b:[0.06485461]
# 355 loss is [4.09273584], parameters w:0.0, b:[0.06497988]
# 356 loss is [4.09281889], parameters w:0.0, b:[0.0651049]
# 357 loss is [4.09290182], parameters w:0.0, b:[0.06522967]
# 358 loss is [4.0929846], parameters w:0.0, b:[0.06535419]
# 359 loss is [4.09306725], parameters w:0.0, b:[0.06547846]
# 360 loss is [4.09314977], parameters w:0.0, b:[0.06560249]
# 361 loss is [4.09323215], parameters w:0.0, b:[0.06572626]
# 362 loss is [4.0933144], parameters w:0.0, b:[0.06584979]
# 363 loss is [4.09339652], parameters w:0.0, b:[0.06597307]
# 364 loss is [4.0934785], parameters w:0.0, b:[0.0660961]
# 365 loss is [4.09356034], parameters w:0.0, b:[0.06621889]
# 366 loss is [4.09364206], parameters w:0.0, b:[0.06634143]
# 367 loss is [4.09372364], parameters w:0.0, b:[0.06646372]
# 368 loss is [4.09380508], parameters w:0.0, b:[0.06658578]
# 369 loss is [4.0938864], parameters w:0.0, b:[0.06670758]
# 370 loss is [4.09396758], parameters w:0.0, b:[0.06682915]
# 371 loss is [4.09404862], parameters w:0.0, b:[0.06695047]
# 372 loss is [4.09412954], parameters w:0.0, b:[0.06707155]
# 373 loss is [4.09421032], parameters w:0.0, b:[0.06719238]
# 374 loss is [4.09429097], parameters w:0.0, b:[0.06731298]
# 375 loss is [4.09437149], parameters w:0.0, b:[0.06743333]
# 376 loss is [4.09445187], parameters w:0.0, b:[0.06755344]
# 377 loss is [4.09453213], parameters w:0.0, b:[0.06767331]
# 378 loss is [4.09461225], parameters w:0.0, b:[0.06779295]
# 379 loss is [4.09469224], parameters w:0.0, b:[0.06791234]
# 380 loss is [4.09477209], parameters w:0.0, b:[0.0680315]
# 381 loss is [4.09485182], parameters w:0.0, b:[0.06815041]
# 382 loss is [4.09493142], parameters w:0.0, b:[0.06826909]
# 383 loss is [4.09501088], parameters w:0.0, b:[0.06838753]
# 384 loss is [4.09509021], parameters w:0.0, b:[0.06850573]
# 385 loss is [4.09516942], parameters w:0.0, b:[0.0686237]
# 386 loss is [4.09524849], parameters w:0.0, b:[0.06874143]
# 387 loss is [4.09532743], parameters w:0.0, b:[0.06885893]
# 388 loss is [4.09540624], parameters w:0.0, b:[0.06897619]
# 389 loss is [4.09548492], parameters w:0.0, b:[0.06909322]
# 390 loss is [4.09556347], parameters w:0.0, b:[0.06921001]
# 391 loss is [4.09564189], parameters w:0.0, b:[0.06932657]
# 392 loss is [4.09572018], parameters w:0.0, b:[0.0694429]
# 393 loss is [4.09579834], parameters w:0.0, b:[0.06955899]
# 394 loss is [4.09587638], parameters w:0.0, b:[0.06967485]
# 395 loss is [4.09595428], parameters w:0.0, b:[0.06979048]
# 396 loss is [4.09603205], parameters w:0.0, b:[0.06990588]
# 397 loss is [4.0961097], parameters w:0.0, b:[0.07002105]
# 398 loss is [4.09618721], parameters w:0.0, b:[0.07013598]
# 399 loss is [4.0962646], parameters w:0.0, b:[0.07025069]
